# %%
import pandas as pd
import seaborn as sns

# %%
main=sns.load_dataset('tips')

# %%
main.loc[main['tip']>3][:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
main[main['time'].str.startswith('D')].count()
# Out:
# total_bill    176
# tip           176
# sex           176
# smoker        176
# day           176
# time          176
# size          176
# dtype: int64

# %%
main['time'].str[:3].count()
# Out:
# 244

# %%
row1={'total_bill':1000,'tip':25,'sex':'Male','smoker':'Yes','day':'Mon','time':'snacks','size':6}

# %%
s1=main.append(row1,ignore_index=True)

# %%
s1[-1:]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 244      1000.0  25.0  Male    Yes  Mon  snacks     6

# %%
s1['tip_per']=s1['tip']/s1['total_bill']*100

# %%
s2=main.copy()

# %%
s01=pd.DataFrame([(500,30,'Male','No','Wed','snacks',10)],columns=['total_bill','tip','sex','smoker','day','time','size'])

# %%
pd.concat([s2,s01],ignore_index=True)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
s2[-1:]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2

# %%
s02=pd.DataFrame({'W':[20,50,30,80]},index=[2,5,7,9])

# %%
pd.concat([s2,s02],axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size     W
# 0         16.99  1.01  Female     No   Sun  Dinner     2   NaN
# 1         10.34  1.66    Male     No   Sun  Dinner     3   NaN
# 2         21.01  3.50    Male     No   Sun  Dinner     3  20.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2   NaN
# 4         24.59  3.61  Female     No   Sun  Dinner     4   NaN
# 5         25.29  4.71    Male     No   Sun  Dinner     4  50.0
# 6          8.77  2.00    Male     No   Sun  Dinner     2   NaN
# 7         26.88  3.12    Male     No   Sun  Dinner     4  30.0
# 8         15.04  1.96    Male     No   Sun  Dinner     2   NaN
# 9         14.78  3.23    Male     No   Sun  Dinner     2  80.0
# 10        10.27  1.71    Male     No   Sun  Dinner     2   NaN
# 11        35.26  5.00  Female     No   Sun  Dinner     4   NaN
# 12        15.42  1.57    Male     No   Sun  Dinner     2   NaN
# 13        18.43  3.00    Male     No   Sun  Dinner     4   NaN
# ...

# %%
s03=main.iloc[:20,:]

# %%
 s04=main.iloc[20:40,:]

# %%
pd.merge(s03,s04,on='day',how='outer')
# Out:
#     total_bill_x  tip_x   sex_x smoker_x  day  time_x  size_x  total_bill_y  \
# 0          16.99   1.01  Female       No  Sun  Dinner       2           NaN
# 1          10.34   1.66    Male       No  Sun  Dinner       3           NaN
# 2          21.01   3.50    Male       No  Sun  Dinner       3           NaN
# 3          23.68   3.31    Male       No  Sun  Dinner       2           NaN
# 4          24.59   3.61  Female       No  Sun  Dinner       4           NaN
# 5          25.29   4.71    Male       No  Sun  Dinner       4           NaN
# 6           8.77   2.00    Male       No  Sun  Dinner       2           NaN
# 7          26.88   3.12    Male       No  Sun  Dinner       4           NaN
# 8          15.04   1.96    Male       No  Sun  Dinner       2           NaN
# 9          14.78   3.23    Male       No  Sun  Dinner       2           NaN
# 10         10.27   1.71    Male       No  Sun  Dinner       2           NaN
# ...

# %%
s04=pd.DataFrame({'name':['vmc','nik','ash','res'],'age':[23,35,60,80]})

# %%
s05=pd.DataFrame({'age':[23,35,60,80],'gen':['young','adult','old']})

# %%
s06=pd.merge(s04,s05,on='age',how='outer')

# %%
x1=pd.Series(['M','F','M','F'],name='gender')

# %%
x1
# Out:
# 0    M
# 1    F
# 2    M
# 3    F
# Name: gender, dtype: object

# %%
s06.join(x1)
# Out:
#   name  age    gen gender
# 0  vmc   23  young      M
# 1  nik   35  adult      F
# 2  ash   60    old      M
# 3  res   80    NaN      F

# %%
main.sort_values(['total_bill']).tail(3)
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 212       48.33   9.00  Male     No  Sat  Dinner     4
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3

# %%
main.sort_values(['total_bill','tip'],ascending=False).head(1)
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
main.sort_index(ascending=False).sample(1)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2

# %%
main.rename(columns={'sex':'gender'},inplace=True)

# %%
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
pd.get_dummies(data=main,columns=['day','gender'])[:10]
# Out:
#    total_bill   tip smoker    time  size  day_Thur  day_Fri  day_Sat  day_Sun  \
# 0       16.99  1.01     No  Dinner     2         0        0        0        1
# 1       10.34  1.66     No  Dinner     3         0        0        0        1
# 2       21.01  3.50     No  Dinner     3         0        0        0        1
# 3       23.68  3.31     No  Dinner     2         0        0        0        1
# 4       24.59  3.61     No  Dinner     4         0        0        0        1
# 5       25.29  4.71     No  Dinner     4         0        0        0        1
# 6        8.77  2.00     No  Dinner     2         0        0        0        1
# 7       26.88  3.12     No  Dinner     4         0        0        0        1
# 8       15.04  1.96     No  Dinner     2         0        0        0        1
# 9       14.78  3.23     No  Dinner     2         0        0        0        1
#
#    gender_Male  gender_Female
# 0            0              1
# 1            1              0
# ...

# %%
s=main.groupby(['day','gender'])

# %%
s.max().sort_index(axis=1,ascending=False)
# Out:
#              total_bill    tip  size
# day  gender
# Thur Male         41.19   6.70     6
#      Female       43.11   5.17     6
# Fri  Male         40.17   4.73     4
#      Female       22.75   4.30     3
# Sat  Male         50.81  10.00     5
#      Female       44.30   6.50     4
# Sun  Male         48.17   6.50     6
#      Female       35.26   5.20     5

# %%
k=main.groupby(['day','time','gender'])

# %%
k.aggregate(['sum','mean','max'])
# Out:
#                    total_bill                       tip                  size  \
#                           sum       mean    max     sum      mean    max  sum
# day  time   gender
# Thur Lunch  Male       561.44  18.714667  41.19   89.41  2.980333   6.70   73
#             Female     516.11  16.648710  43.11   79.42  2.561935   5.17   77
#      Dinner Female      18.78  18.780000  18.78    3.00  3.000000   3.00    2
# Fri  Lunch  Male        34.16  11.386667  13.42    5.70  1.900000   2.20    5
#             Female      55.76  13.940000  16.27   10.98  2.745000   3.48    9
#      Dinner Male       164.41  23.487143  40.17   21.23  3.032857   4.73   16
#             Female      71.55  14.310000  22.75   14.05  2.810000   4.30   10
# Sat  Dinner Male      1227.35  20.802542  50.81  181.95  3.083898  10.00  156
#             Female     551.05  19.680357  44.30   78.45  2.801786   6.50   63
# Sun  Dinner Male      1269.46  21.887241  48.17  186.78  3.220345   6.50  163
# ...

# %%
k.indices
# Out:
# {('Thur',
#   'Lunch',
#   'Male'): array([ 77,  78,  79,  80,  81,  83,  84,  86,  87,  88,  89, 120, 122,
#         123, 126, 129, 130, 138, 141, 142, 148, 149, 192, 193, 194, 195,
#         196, 199, 200, 204], dtype=int64),
#  ('Thur',
#   'Lunch',
#   'Female'): array([ 82,  85, 117, 118, 119, 121, 124, 125, 127, 128, 131, 132, 133,
#         134, 135, 136, 137, 139, 140, 143, 144, 145, 146, 147, 191, 197,
#         198, 201, 202, 203, 205], dtype=int64),
#  ('Thur', 'Dinner', 'Female'): array([243], dtype=int64),
#  ('Fri', 'Lunch', 'Male'): array([220, 222, 224], dtype=int64),
#  ('Fri', 'Lunch', 'Female'): array([221, 223, 225, 226], dtype=int64),
#  ('Fri', 'Dinner', 'Male'): array([90, 91, 95, 96, 97, 98, 99], dtype=int64),
#  ('Fri', 'Dinner', 'Female'): array([ 92,  93,  94, 100, 101], dtype=int64),
#  ('Sat',
#   'Dinner',
#   'Male'): array([ 19,  20,  23,  24,  25,  26,  27,  28,  30,  31,  34,  35,  36,
# ...

# %%
k1=main.groupby('day')

# %%
k2=k1.get_group('Fri')

# %%
k2[k2['tip']>3]
# Out:
#      total_bill   tip  gender smoker  day    time  size
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2

# %%
import scipy.stats as stat

# %%
marks=[590,584,560,450,260,390,300]
attend=[90,84,84,82,70,75,73]
res=stat.linregress(attend,marks)

# %%
res.intercept+(90)*res.slope
# Out:
# 634.5761772853189

# %%
main.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
pd.get_dummies(data=main,columns=['day','gender']).sample(7)
# Out:
#      total_bill   tip smoker    time  size  day_Thur  day_Fri  day_Sat  \
# 36        16.31  2.00     No  Dinner     3         0        0        1
# 112       38.07  4.00     No  Dinner     3         0        0        0
# 185       20.69  5.00     No  Dinner     5         0        0        0
# 16        10.33  1.67     No  Dinner     3         0        0        0
# 219       30.14  3.09    Yes  Dinner     4         0        0        1
# 234       15.53  3.00    Yes  Dinner     2         0        0        1
# 207       38.73  3.00    Yes  Dinner     4         0        0        1
#
#      day_Sun  gender_Male  gender_Female
# 36         0            1              0
# 112        1            1              0
# 185        1            1              0
# 16         1            0              1
# 219        0            0              1
# 234        0            1              0
# 207        0            1              0

# %%
val=main.groupby(['day','time'])

# %%
val.get_group(('Fri','Dinner'))
# Out:
#      total_bill   tip  gender smoker  day    time  size
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2
# 99        12.46  1.50    Male     No  Fri  Dinner     2
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2

# %%
main.isna().head()
# Out:
#    total_bill    tip  gender  smoker    day   time   size
# 0       False  False   False   False  False  False  False
# 1       False  False   False   False  False  False  False
# 2       False  False   False   False  False  False  False
# 3       False  False   False   False  False  False  False
# 4       False  False   False   False  False  False  False

# %%
m2=main.copy()
import numpy as np

# %%
m2.loc[4:7,['smoker','day']]=np.nan

# %%
m2[4:7]
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 4       24.59  3.61  Female    NaN  NaN  Dinner     4
# 5       25.29  4.71    Male    NaN  NaN  Dinner     4
# 6        8.77  2.00    Male    NaN  NaN  Dinner     2

# %%
m2['smoker'].isna().count()
# Out:
# 244

# %%
m2[m2.isna().any(axis=1)]
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 4       24.59  3.61  Female    NaN  NaN  Dinner     4
# 5       25.29  4.71    Male    NaN  NaN  Dinner     4
# 6        8.77  2.00    Male    NaN  NaN  Dinner     2
# 7       26.88  3.12    Male    NaN  NaN  Dinner     4

# %%
c1=pd.cut(m2['total_bill'],bins=[0,20,30,40],labels=['bad','okay','good'])

# %%
xv=pd.Series(c1,name='vals')

# %%
m3=m2.join(xv)

# %%
m3[m3['vals']=='good'][['total_bill','time']].count()
# Out:
# total_bill    22
# time          22
# dtype: int64

# %%
m2.pivot_table(index=['total_bill','tip'],columns=['gender','day'],aggfunc='sum')
# Out:
#                  size
# gender           Male                Female
# day              Thur  Fri  Sat  Sun   Thur  Fri  Sat  Sun
# total_bill tip
# 3.07       1.00   NaN  NaN  NaN  NaN    NaN  NaN  1.0  NaN
# 5.75       1.00   NaN  NaN  NaN  NaN    NaN  2.0  NaN  NaN
# 7.25       1.00   NaN  NaN  NaN  NaN    NaN  NaN  1.0  NaN
#            5.15   NaN  NaN  NaN  2.0    NaN  NaN  NaN  NaN
# 7.51       2.00   2.0  NaN  NaN  NaN    NaN  NaN  NaN  NaN
# 7.56       1.44   2.0  NaN  NaN  NaN    NaN  NaN  NaN  NaN
# 7.74       1.44   NaN  NaN  2.0  NaN    NaN  NaN  NaN  NaN
# 8.35       1.50   NaN  NaN  NaN  NaN    2.0  NaN  NaN  NaN
# 8.51       1.25   NaN  NaN  NaN  NaN    2.0  NaN  NaN  NaN
# 8.52       1.48   2.0  NaN  NaN  NaN    NaN  NaN  NaN  NaN
# 8.58       1.92   NaN  1.0  NaN  NaN    NaN  NaN  NaN  NaN
# 9.55       1.45   NaN  NaN  2.0  NaN    NaN  NaN  NaN  NaN
# 9.60       4.00   NaN  NaN  NaN  NaN    NaN  NaN  NaN  2.0
# ...
