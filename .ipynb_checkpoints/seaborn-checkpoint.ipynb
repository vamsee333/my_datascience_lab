# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

# %%
ship=sns.load_dataset('titanic')

# %%
tips=sns.load_dataset('tips')

# %%
ship.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
ship.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x='who',y='age',hue='survived',data=ship)

# %%
sns.barplot(x='who',y='age',hue='survived',data=ship,palette='Blues_d')

# %%
sns.boxplot(x='who',y='age',hue='survived',data=ship)

# %%
ship.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.barplot(x='pclass',y='age',hue='survived',data=ship,palette='Blues_d')

# %%
sns.catplot(x='pclass',y='age',hue='survived',data=ship)

# %%
ship[ship['survived']==1]['age'].max()
# Out:
# 80.0

# %%
sns.catplot('alive',col='deck',data=ship[ship.deck.notnull()],kind='count',col_wrap=4,height=5)

# %%
flights=sns.load_dataset('flights')

# %%
flights.head(3)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132

# %%
sns.barplot(x='year',y='passengers',data=flights,ci=False)

# %%
sns.scatterplot(x='year',y='passengers',data=flights)

# %%
sns.scatterplot(x='deck',y='age',hue='survived',data=ship)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot(y='tip',x='total_bill',hue='time',data=tips)

# %%
from matplotlib.colors import LogNorm
sns.lineplot(x='total_bill',y='tip',hue='day',data=tips,markers=True,hue_norm=LogNorm())

# %%
import seaborn as sns

# %%
tip=sns.load_dataset('tips')

# %%
tip.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fly=sns.load_dataset('flights')

# %%
work=sns.load_dataset('exercise')

# %%
fly.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
work.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
work.head(3)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest

# %%
type(work.time[1])
import pandas as pd

# %%
work['time']=work.time.str[:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-bf999430308b> in <module>
# ----> 1 work['time']=work.time.str[:2].toint()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'toint'

# %%
work.head(4)

# %%
type(work.time[1])
# Out:
# str

# %%
x=pd.to_numeric(work.time.str[:2])

# %%
type(x[1])
# Out:
# numpy.int64

# %%
work['time']=x

# %%
work.head(2)
# Out:
#    Unnamed: 0  id     diet  pulse  time  kind
# 0           0   1  low fat     85     1  rest
# 1           1   1  low fat     85    15  rest

# %%
tip.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### regplot with tip data frame

# %%
a=sns.regplot(x='tip',y='total_bill',data=tip,color='r')

# %% [markdown]
# ### lmplot with tip data frame

# %%
b=sns.lmplot(x='tip',y='total_bill',hue='time',col='day',data=tip,markers=['d','+'])

# %% [markdown]
# ### catplot with tip DF

# %%
c=sns.catplot(y='total_bill',x='time',hue='day',kind='strip',col='sex',data=tip,linewidth=1)

# %%
c=sns.catplot(x='time',y='tip',col='day',data=tip,kind='violin')

# %%
d=sns.catplot(x='day',y='tip',data=tip,hue='sex',kind='swarm',col='time')

# %%
work.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
work.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse  time  kind
# 0           0   1  low fat     85     1  rest
# 1           1   1  low fat     85    15  rest
# 2           2   1  low fat     88    30  rest
# 3           3   2  low fat     90     1  rest
# 4           4   2  low fat     92    15  rest

# %%
e=sns.catplot(x='kind',y='pulse',hue='diet',kind='boxen',data=work)
e=sns.stripplot(x='kind',y='pulse',hue='diet',data=work)

# %% [markdown]
# ### point plot in catplot

# %%
f=sns.catplot(x='day',y='tip',data=tip,kind='point')
import numpy as np

# %%
f=sns.catplot(x='day',y='tip',hue='sex',data=tip,kind='point',estimator=np.mean,dodge=True)

# %% [markdown]
# ### bar plot in catplot for tip DF

# %%
g=sns.catplot(x='sex',y='total_bill',hue='time',col='day',data=tip,kind='bar')

# %% [markdown]
# ### count plot in catplot for tip DF

# %%
h=sns.catplot(x='day',data=tip,hue='time',col='sex',kind='count')

# %% [markdown]
# ### pairplot with tip DF

# %%
i=sns.pairplot(tip,vars=['total_bill','tip'])

# %%
i=sns.pairplot(tip,kind='reg',hue='sex')

# %% [markdown]
# ## distribution plot

# %% [markdown]
# ### joint plot example

# %%
j=sns.jointplot(x='tip',y='total_bill',data=tip,kind='kde')

# %%
j=sns.jointplot(x='total_bill',y='tip',data=tip,kind='hex')

# %%
j=sns.jointplot(x='total_bill',y='tip',data=tip,kind='reg')

# %%
x,y=np.random.randn(2,400)

# %%
k=sns.jointplot(x,y,kind='kde',color='g')

# %% [markdown]
# ### distplot with tip DF

# %%
tem=np.random.randint(1,20,15)
val=pd.Series()

# %%
val=pd.Series(tem,name='vals')

# %%
val
# Out:
# 0      6
# 1      3
# 2     13
# 3     19
# 4     11
# 5     12
# 6     13
# 7     12
# 8      8
# 9     13
# 10     5
# 11    17
# 12     4
# 13     7
# 14     3
# Name: vals, dtype: int32

# %%
k=sns.distplot(val)

# %% [markdown]
# ### kde (kernal density estimater) plot with tip DF

# %%
l=sns.kdeplot(tip.total_bill,tip.tip,color='b',shade=True)

# %%
tip.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
val=tip[tip['tip']<3]
val2=tip[tip['tip']>=4]

# %%
m=sns.kdeplot(val.tip,val.total_bill,shade=True,cmap='Reds',shade_lowest=False)
m=sns.kdeplot(val2.tip,val2.total_bill,shade=True,cmap='Blues',shade_lowest=False)
